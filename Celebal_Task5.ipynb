# %% [markdown]
# <a href="https://colab.research.google.com/github/kouliki/celebal_task5/blob/main/Celebal_Task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/titanic.csv')

# %% [markdown]
# # Data Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
cols = ['Name', 'Ticket', 'Cabin']
df = df.drop(cols, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Fare         891 non-null    float64
#  8   Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.8+ KB

# %%
df.isna()
# Out:
#      PassengerId  Survived  Pclass    Sex    Age  SibSp  Parch   Fare  \
# 0          False     False   False  False  False  False  False  False
# 1          False     False   False  False  False  False  False  False
# 2          False     False   False  False  False  False  False  False
# 3          False     False   False  False  False  False  False  False
# 4          False     False   False  False  False  False  False  False
# ..           ...       ...     ...    ...    ...    ...    ...    ...
# 886        False     False   False  False  False  False  False  False
# 887        False     False   False  False  False  False  False  False
# 888        False     False   False  False   True  False  False  False
# 889        False     False   False  False  False  False  False  False
# 890        False     False   False  False  False  False  False  False
#
#      Embarked
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ..        ...
# 886     False
# ...

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  712 non-null    int64
#  1   Survived     712 non-null    int64
#  2   Pclass       712 non-null    int64
#  3   Sex          712 non-null    object
#  4   Age          712 non-null    float64
#  5   SibSp        712 non-null    int64
#  6   Parch        712 non-null    int64
#  7   Fare         712 non-null    float64
#  8   Embarked     712 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 55.6+ KB

# %% [markdown]
# # Missing values

# %%
dummies=[]
cols=['Pclass', 'Sex', 'Embarked']
for col in cols:
  dummies.append(pd.get_dummies(df[col]))

# %%
titanic_dummies = pd.concat(dummies, axis=1)

# %%
df = pd.concat((df,titanic_dummies), axis=1)

# %%
df['Age'] = df['Age'].interpolate()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 0 to 890
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  712 non-null    int64
#  1   Survived     712 non-null    int64
#  2   Pclass       712 non-null    int64
#  3   Sex          712 non-null    object
#  4   Age          712 non-null    float64
#  5   SibSp        712 non-null    int64
#  6   Parch        712 non-null    int64
#  7   Fare         712 non-null    float64
#  8   Embarked     712 non-null    object
#  9   1            712 non-null    bool
#  10  2            712 non-null    bool
#  11  3            712 non-null    bool
#  12  female       712 non-null    bool
#  13  male         712 non-null    bool
#  14  C            712 non-null    bool
#  15  Q            712 non-null    bool
#  16  S            712 non-null    bool
# dtypes: bool(8), float64(2), int64(5), object(2)
# memory usage: 61.2+ KB

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # Normalization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df[['Age', 'Fare']] = scaler.fit_transform(df[['Age', 'Fare']])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex       Age  SibSp  Parch      Fare  \
# 0            1         0       3    male -0.527669      1      0 -0.516380
# 1            2         1       1  female  0.577094      1      0  0.694046
# 2            3         1       3  female -0.251478      0      0 -0.503620
# 3            4         1       1  female  0.369951      1      0  0.350326
# 4            5         0       3    male  0.369951      0      0 -0.501257
#
#   Embarked      1      2      3  female   male      C      Q      S
# 0        S  False  False   True   False   True  False  False   True
# 1        C   True  False  False    True  False   True  False  False
# 2        S  False  False   True    True  False  False  False   True
# 3        S   True  False  False    True  False  False  False   True
# 4        S  False  False   True   False   True  False  False   True

# %% [markdown]
# # Encoding

# %%
df = pd.get_dummies(df, columns=['Sex', 'Embarked'], drop_first=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass       Age  SibSp  Parch      Fare      1  \
# 0            1         0       3 -0.527669      1      0 -0.516380  False
# 1            2         1       1  0.577094      1      0  0.694046   True
# 2            3         1       3 -0.251478      0      0 -0.503620  False
# 3            4         1       1  0.369951      1      0  0.350326   True
# 4            5         0       3  0.369951      0      0 -0.501257  False
#
#        2      3  female   male      C      Q      S  Sex_male  Embarked_Q  \
# 0  False   True   False   True  False  False   True      True       False
# 1  False  False    True  False   True  False  False     False       False
# 2  False   True    True  False  False  False   True     False       False
# 3  False  False    True  False  False  False   True     False       False
# 4  False   True   False   True  False  False   True      True       False
#
#    Embarked_S
# 0        True
# 1       False
# 2        True
# ...

# %% [markdown]
# # Feature Engineering

# %%
df['fsmilySize']=df['SibSp'] + df['Parch'] + 1

# %%
df
# Out:
#      PassengerId  Survived  Pclass       Age  SibSp  Parch      Fare      1  \
# 0              1         0       3 -0.527669      1      0 -0.516380  False
# 1              2         1       1  0.577094      1      0  0.694046   True
# 2              3         1       3 -0.251478      0      0 -0.503620  False
# 3              4         1       1  0.369951      1      0  0.350326   True
# 4              5         0       3  0.369951      0      0 -0.501257  False
# ..           ...       ...     ...       ...    ...    ...       ...    ...
# 885          886         0       3  0.646142      0      5 -0.102875  False
# 886          887         0       2 -0.182430      0      0 -0.407687  False
# 887          888         1       1 -0.734812      0      0 -0.086335   True
# 889          890         1       1 -0.251478      0      0 -0.086335   True
# 890          891         0       3  0.162808      0      0 -0.506928  False
#
# ...
